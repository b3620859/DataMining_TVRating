# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import pandas as pd
import requests
import csv

# %%
src = requests.get('http://www1.xkm.com.tw/hr/DATA/HR190311.htm')
src_text = src.text
print(src_text)
# Out:
# <html xmlns:o="urn:schemas-microsoft-com:office:office"
# xmlns:x="urn:schemas-microsoft-com:office:excel"
# xmlns="http://www.w3.org/TR/REC-html40">
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=big5">
# <meta name=ProgId content=Excel.Sheet>
# <meta name=Generator content="Microsoft Excel 11">
# <link rel=File-List href="hr190311.files/filelist.xml">
# <link rel=Edit-Time-Data href="hr190311.files/editdata.mso">
# <link rel=OLE-Object-Data href="hr190311.files/oledata.mso">
# <!--[if gte mso 9]><xml>
#  <o:DocumentProperties>
#   <o:Author>User</o:Author>
#   <o:LastAuthor>User</o:LastAuthor>
#   <o:Created>2019-03-12T10:12:25Z</o:Created>
#   <o:LastSaved>2019-03-12T10:12:28Z</o:LastSaved>
#   <o:Company>CMT</o:Company>
#   <o:Version>11.6568</o:Version>
#  </o:DocumentProperties>
# </xml><![endif]-->
# <style>
# <!--table
# 	{mso-displayed-decimal-separator:"\.";
# 	mso-displayed-thousand-separator:"\,";}
# @page
# 	{margin:1.0in .75in 1.0in .75in;
# ...

# %%
dfs = pd.read_html('http://www1.xkm.com.tw/hr/DATA/HR190311.htm')

# %%
rating = dfs[0]
rating
# Out:
#                                                0       1            2      3  \
# 0                           潤利公司【家庭收視率】排名表  （日報）     NaN          NaN    NaN
# 1                               排名頻道：（無線＋有線）６６頻道     NaN          NaN    NaN
# 2                  日期:2019/03/11  時段:18:00~22:00     NaN          NaN    NaN
# 3                                             排名      台別         節目名稱   節目時間
# 4                                              1      民視       大時代雀巢立  20:00
# 5                                              2     三立台          炮仔聲  20:00
# 6                                              3      台視       台視晚間新聞  19:00
# 7                                              4      民視       民視七點晚間  19:00
# 8                                              5     三立台         戲說台灣  19:30
# 9                                              6     中文台          如懿傳  21:00
# 10                                             7    CTiN        新聞深喉嚨  20:00
# ...

# %%
rating.columns = rating.loc[3]
rating
# Out:
# 3                                             排名      台別         節目名稱   節目時間  \
# 0                           潤利公司【家庭收視率】排名表  （日報）     NaN          NaN    NaN
# 1                               排名頻道：（無線＋有線）６６頻道     NaN          NaN    NaN
# 2                  日期:2019/03/11  時段:18:00~22:00     NaN          NaN    NaN
# 3                                             排名      台別         節目名稱   節目時間
# 4                                              1      民視       大時代雀巢立  20:00
# 5                                              2     三立台          炮仔聲  20:00
# 6                                              3      台視       台視晚間新聞  19:00
# 7                                              4      民視       民視七點晚間  19:00
# 8                                              5     三立台         戲說台灣  19:30
# 9                                              6     中文台          如懿傳  21:00
# 10                                             7    CTiN        新聞深喉嚨  20:00
# ...

# %%
# rating = rating.ix[4:10,0:7]
# rating.columns = [u'排名', u'台別', u'節目名稱', u'節目時間', u'收視率', u'C.P.M.', u'10秒廣告價', u'+-誤差']
# #rating.rows = ['1', '2', '3', '4', '5', '6', '7']
# rating

# %%
rating.drop([0,1,2,3,124,125,126],inplace = True)
rating
# Out:
# 3     排名      台別         節目名稱   節目時間   收視率 C.P.M. 10秒廣告價  +-誤差
# 4      1      民視       大時代雀巢立  20:00  6.05     62  75000  1.65
# 5      2     三立台          炮仔聲  20:00  3.08    121  75000   1.2
# 6      3      台視       台視晚間新聞  19:00  2.07     79  33000  0.99
# 7      4      民視       民視七點晚間  19:00  1.96     84  33000  0.96
# 8      5     三立台         戲說台灣  19:30  1.79     83  30000  0.92
# 9      6     中文台          如懿傳  21:00  1.68     44  15000  0.89
# 10     7    CTiN        新聞深喉嚨  20:00  1.67    104  35000  0.89
# 11     8      中視       中視新聞全球  19:00  1.59    103  33000  0.87
# 12     9      台視       女力報到女兵  21:00  1.51    108  33000  0.85
# 13    10   TVBS歡       女兵日記女力  20:00  1.47     84  25000  0.83
# 14    11    CTiN     中天1800晚間  17:30  1.41    141  40000  0.82
# 15    12      台視     1830蠟筆小新  18:30  1.39    118  33000  0.81
# 16    13    CTiN        新聞龍捲風  21:55  1.37    127  35000  0.81
# 17    14     民視新       民視晚間新聞  18:30  1.33    123  33000  0.79
# ...

# %%
rating.reset_index(drop = True, inplace=True)
rating
# Out:
# 3     排名      台別         節目名稱   節目時間   收視率 C.P.M. 10秒廣告價  +-誤差
# 0      1      民視       大時代雀巢立  20:00  6.05     62  75000  1.65
# 1      2     三立台          炮仔聲  20:00  3.08    121  75000   1.2
# 2      3      台視       台視晚間新聞  19:00  2.07     79  33000  0.99
# 3      4      民視       民視七點晚間  19:00  1.96     84  33000  0.96
# 4      5     三立台         戲說台灣  19:30  1.79     83  30000  0.92
# 5      6     中文台          如懿傳  21:00  1.68     44  15000  0.89
# 6      7    CTiN        新聞深喉嚨  20:00  1.67    104  35000  0.89
# 7      8      中視       中視新聞全球  19:00  1.59    103  33000  0.87
# 8      9      台視       女力報到女兵  21:00  1.51    108  33000  0.85
# 9     10   TVBS歡       女兵日記女力  20:00  1.47     84  25000  0.83
# 10    11    CTiN     中天1800晚間  17:30  1.41    141  40000  0.82
# 11    12      台視     1830蠟筆小新  18:30  1.39    118  33000  0.81
# 12    13    CTiN        新聞龍捲風  21:55  1.37    127  35000  0.81
# 13    14     民視新       民視晚間新聞  18:30  1.33    123  33000  0.79
# ...

# %%
rating.to_csv('test_rating.csv',index=False,encoding = 'utf-8-sig')

# %%
# 開啟 CSV 檔案
import pandas as pd
import csv
df = pd.read_csv('160331.csv')  

pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth',10)

# %%
df

# %%
df=df[ ~ df['10秒廣告價'].isin([0])]

# %%
df
